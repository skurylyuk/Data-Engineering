# %%
# Explore safety issues in FDA

# %%
import pandas as pd
from sodapy import Socrata
from sqlalchemy import create_engine, inspect
import sqlite3

# %%
client = Socrata("data.cityofchicago.org", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("4ijn-s7e5", limit=100000)

# %%
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
#       inspection_id                            dba_name  \
# 0           2554087              Tropical Smoothie Cafe
# 1           2554077              MAYFAIR EARLY LEARNING
# 2           2554079                            MOCHINUT
# 3           2554086   GOLDEN STAR TOBACCO & GROCERY INC
# 4           2554099  PRESENCE CHICAGO HOSPITALS NETWORK
# ...             ...                                 ...
# 99995       1953816      NEW ENGLAND SEAFOOD COMPANY FL
# 99996       1953835                       CENTRO MARKET
# 99997       1953693                  CVS/PHARMACY #8753
# 99998       1953754                            BAR TOMA
# 99999       1953719                        LOS CARBONES
#
#                                 aka_name license_  \
# 0                 Tropical Smoothie Cafe  2840460
# 1                 MAYFAIR EARLY LEARNING  2308804
# 2                               MOCHINUT  2827751
# 3      GOLDEN STAR TOBACCO & GROCERY INC  2835873
# 4                    ST. JOSEPH HOSPITAL  1144381
# ...                                  ...      ...
# 99995        NEW ENGLAND SEAFOOD COMPANY  2108692
# 99996                   EL CENTRO MARKET    66257
# 99997                 CVS/PHARMACY #8753  1695423
# 99998                           BAR TOMA    17495
# 99999                       LOS CARBONES  2483107
#
#                       facility_type             risk  \
# 0                        Restaurant  Risk 2 (Medium)
# 1      Children's Services Facility    Risk 1 (High)
# 2                        Restaurant  Risk 2 (Medium)
# 3                     Grocery Store     Risk 3 (Low)
# 4                        Restaurant    Risk 1 (High)
# ...                             ...              ...
# 99995                    Restaurant    Risk 1 (High)
# 99996                 Grocery Store    Risk 1 (High)
# 99997                 Grocery Store     Risk 3 (Low)
# 99998                    Restaurant    Risk 1 (High)
# 99999                    Restaurant    Risk 1 (High)
#
#                          address     city state    zip  \
# 0            4874 N LINCOLN AVE   CHICAGO    IL  60625
# 1             4719 N PULASKI RD   CHICAGO    IL  60630
# 2              1139 W TAYLOR ST   CHICAGO    IL  60607
# 3      8637 S COTTAGE GROVE AVE   CHICAGO    IL  60619
# 4          2900 N LAKE SHORE DR   CHICAGO    IL  60657
# ...                          ...      ...   ...    ...
# 99995        3341 N LINCOLN AVE   CHICAGO    IL  60657
# 99996      5153-59 S KEDZIE AVE   CHICAGO    IL  60632
# 99997      3637 N SOUTHPORT AVE   CHICAGO    IL  60613
# 99998          110 E PEARSON ST   CHICAGO    IL  60611
# 99999     9710 S COMMERCIAL AVE   CHICAGO    IL  60617
#
#                inspection_date        inspection_type results  \
# 0      2022-04-08T00:00:00.000                License    Pass
# 1      2022-04-08T00:00:00.000  License Re-Inspection    Pass
# 2      2022-04-08T00:00:00.000                License    Pass
# 3      2022-04-08T00:00:00.000                License    Fail
# 4      2022-04-08T00:00:00.000                Canvass    Fail
# ...                        ...                    ...     ...
# 99995  2016-09-06T00:00:00.000  Canvass Re-Inspection    Pass
# 99996  2016-09-06T00:00:00.000                Canvass    Fail
# 99997  2016-09-02T00:00:00.000                Canvass    Pass
# 99998  2016-09-02T00:00:00.000                Canvass    Pass
# 99999  2016-09-02T00:00:00.000                License    Pass
#
#                                               violations            latitude  \
# 0      36. THERMOMETERS PROVIDED & ACCURATE - Comment...  41.970550218072056
# 1                                                    NaN  41.966991428127784
# 2      36. THERMOMETERS PROVIDED & ACCURATE - Comment...   41.86932255085863
# 3      5. PROCEDURES FOR RESPONDING TO VOMITING AND D...    41.7373613466866
# 4      10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...   41.93440298707838
# ...                                                  ...                 ...
# 99995  30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABEL...  41.942572824782836
# 99996  12. HAND WASHING FACILITIES: WITH SOAP AND SAN...  41.799257043707684
# 99997  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...   41.94817860023431
# 99998  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...   41.89765954569349
# 99999                                                NaN   41.71874410804698
#
#                 longitude                                           location
# 0      -87.68993650758067  {'latitude': '-87.68993650758067', 'longitude'...
# 1      -87.72784541288395  {'latitude': '-87.72784541288395', 'longitude'...
# 2      -87.65574774059874  {'latitude': '-87.65574774059874', 'longitude'...
# 3      -87.60469580542522  {'latitude': '-87.60469580542522', 'longitude'...
# 4      -87.63680583708285  {'latitude': '-87.63680583708285', 'longitude'...
# ...                   ...                                                ...
# 99995  -87.67051293219696  {'latitude': '-87.67051293219696', 'longitude'...
# 99996  -87.70357470655833  {'latitude': '-87.70357470655833', 'longitude'...
# 99997  -87.66389687202293  {'latitude': '-87.66389687202293', 'longitude'...
# 99998  -87.62553180957474  {'latitude': '-87.62553180957474', 'longitude'...
# 99999  -87.55117213195877  {'latitude': '-87.55117213195877', 'longitude'...
#
# [100000 rows x 17 columns]

# %%
results_df=results_df.drop(columns= ["location"])

# %%
results_df=results_df[results_df["violations"].notna()]

# %%
engine = create_engine("sqlite:///inspections.db", echo=False)

# connect to the sql database
conn = sqlite3.connect('inspections.db')

# create the ability to perform logic on the database
c = conn.cursor()

# create the table in the database
c.execute('CREATE TABLE IF NOT EXISTS food_inspections '\
          '(inspection_id TEXT, dba_name TEXT, aka_name TEXT, license_ TEXT, facility_type TEXT, risk TEXT, address TEXT, '\
          'city TEXT, state TEXT, zip TEXT, inspection_date TEXT, inspection_type TEXT, results TEXT, violations TEXT, '\
          'R1_1 TEXT, R1_2 TEXT, R1_3 TEXT, R2_1 TEXT, R2_2 TEXT, R2_3 TEXT, RS_1 TEXT, RS_2 TEXT, RS_3 TEXT, '\
          'latitude TEXT, longituide TEXT, locations TEXT, '\
          'PRIMARY KEY (inspection_id))')
# commit the stock table
conn.commit()

# print table name
print(inspect(engine).get_table_names())
# Out:
# ['food_inspections']

# %%
results_df.to_sql('food_inspections', conn, if_exists='replace', index=False)
